# %% [markdown]
# # Final project - top university research

# %% [markdown]
# For this project, we would like to predict whether a us university is Top200 in the world or not. We have three group of features: internal, external and mixed. And we seek to discover which group of factors result in best predictions.

# %% [markdown]
# ## Data intake

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
import graphviz 
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import tree
from sklearn.neighbors import KNeighborsClassifier

# %%
# internal data: university statistics
dfRank = pd.read_csv('https://raw.githubusercontent.com/oca510/ds320FinalProject/main/datasets/cwurData.csv')
dfInfo = pd.read_csv('https://raw.githubusercontent.com/oca510/ds320FinalProject/main/datasets/world-universities.csv')
# external data: demographic statistics
dfDemo = pd.read_csv('https://raw.githubusercontent.com/oca510/ds320FinalProject/main/datasets/acs2017_county_data.csv')
dfEdu = pd.read_csv('https://raw.githubusercontent.com/oca510/ds320FinalProject/main/datasets/education.csv')

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}
    
# invert the dictionary
abbrev_to_us_state = dict(map(reversed, us_state_to_abbrev.items()))

# %%
dfRank
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 3                 1                    10                 24
# 4                 4                     2                 29
# ...             ...                   ...                ...
# 2195              7                   367                567
# 2196              4                   236                566
# 2197             18                   367                549
# 2198             40                   367                567
# 2199             83                   367                567
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 3                      4            16         16         11           NaN
# 4                      7            37         22         22           NaN
# ...                  ...           ...        ...        ...           ...
# 2195                 218           926        845        812         969.0
# 2196                 218           997        908        645         981.0
# 2197                 218           830        823        812         975.0
# 2198                 218           886        974        812         975.0
# 2199                 218           861        991        812         981.0
#
#       patents   score  year
# 0           5  100.00  2012
# 1           1   91.67  2012
# 2          15   89.50  2012
# 3          50   86.17  2012
# 4          18   85.21  2012
# ...       ...     ...   ...
# 2195      816   44.03  2015
# 2196      871   44.03  2015
# 2197      824   44.03  2015
# 2198      651   44.02  2015
# 2199      547   44.02  2015
#
# [2200 rows x 14 columns]

# %%
dfInfo
# Out:
#                  X             Y  OBJECTID  IPEDSID  \
# 0    -8.765605e+06  5.318192e+06         1   189556
# 1    -8.231383e+06  4.975222e+06         2   190682
# 2    -8.247285e+06  5.032103e+06         3   195058
# 3    -8.208890e+06  5.008471e+06         4   193122
# 4    -8.969252e+06  4.965197e+06         5   204884
# ...            ...           ...       ...      ...
# 6852 -1.009017e+07  4.687538e+06      6853   262031
# 6853 -8.319680e+06  4.906794e+06      6854   186283
# 6854 -8.324179e+06  4.905072e+06      6855   187134
# 6855 -9.284880e+06  5.219144e+06      6856   170806
# 6856 -8.589346e+06  4.735792e+06      6857   163426
#
#                                                    NAME  \
# 0                     BRYANT & STRATTON COLLEGE-AMHERST
# 1                                    CUNY SCHOOL OF LAW
# 2                            ROCKLAND COMMUNITY COLLEGE
# 3     SOUTHERN WESTCHESTER BOCES-PRACTICAL NURSING P...
# 4                     OHIO VALLEY COLLEGE OF TECHNOLOGY
# ...                                                 ...
# 6852                       ST CHARLES COMMUNITY COLLEGE
# 6853                                   RIDER UNIVERSITY
# 6854                          THE COLLEGE OF NEW JERSEY
# 6855                                 MADONNA UNIVERSITY
# 6856                                 MONTGOMERY COLLEGE
#
#                        ADDRESS              CITY STATE    ZIP           ZIP4  \
# 0     3650 MILLERSPORT HIGHWAY         GETZVILLE    NY  14068  NOT AVAILABLE
# 1               2 COURT SQUARE  LONG ISLAND CITY    NY  11101  NOT AVAILABLE
# 2               145 COLLEGE RD           SUFFERN    NY  10901           3699
# 3        450 MAMARONECK AVENUE          HARRISON    NY  10528  NOT AVAILABLE
# 4        15258 STATE ROUTE 170    EAST LIVERPOOL    OH  43920           9585
# ...                        ...               ...   ...    ...            ...
# 6852   4601 MID RIVERS MALL DR       COTTLEVILLE    MO  63376           0975
# 6853        2083 LAWRENCE ROAD     LAWRENCEVILLE    NJ   8648           3099
# 6854      2000 PENNINGTON ROAD             EWING    NJ   8628           7718
# 6855      36600 SCHOOLCRAFT RD           LIVONIA    MI  48150           1176
# 6856        51 MANNAKEE STREET         ROCKVILLE    MD  20850  NOT AVAILABLE
#
#       ...                                              ALIAS  SIZE_SET  \
# 0     ...                                      NOT AVAILABLE         6
# 1     ...                       LAW SCHOOL | CUNY LAW SCHOOL        18
# 2     ...                                      NOT AVAILABLE         3
# 3     ...                                      NOT AVAILABLE        -2
# 4     ...                                      NOT AVAILABLE         1
# ...   ...                                                ...       ...
# 6852  ...                                                SCC         3
# 6853  ...                                      NOT AVAILABLE        14
# 6854  ...                                               TCNJ        14
# 6855  ...                                      NOT AVAILABLE         9
# 6856  ...  MONTGOMERY COLLEGE - ROCKVILLE |MONTGOMERY COL...         5
#
#      INST_SIZE  PT_ENROLL FT_ENROLL TOT_ENROLL HOUSING  DORM_CAP  TOT_EMP  \
# 0            1        141       176        317       2      -999       79
# 1            1        165       418        583       2      -999      201
# 2            3       3317      3542       6859       2      -999      901
# 3            1         54        52        106       2      -999       31
# 4            1         25       176        201       2      -999       30
# ...        ...        ...       ...        ...     ...       ...      ...
# 6852         3       3102      3167       6269       2      -999      836
# 6853         2        986      3838       4824       1      2716     1213
# 6854         3        693      6993       7686       1      3994     1631
# 6855         2       1499      1545       3044       1       400      612
# 6856         5      14149      7571      21720       2      -999     2991
#
#          SHELTER_ID
# 0     NOT AVAILABLE
# 1     NOT AVAILABLE
# 2     NOT AVAILABLE
# 3     NOT AVAILABLE
# 4     NOT AVAILABLE
# ...             ...
# 6852  NOT AVAILABLE
# 6853  NOT AVAILABLE
# 6854  NOT AVAILABLE
# 6855  NOT AVAILABLE
# 6856  NOT AVAILABLE
#
# [6857 rows x 45 columns]

# %%
dfDemo
# Out:
#       CountyId        State               County  TotalPop    Men   Women  \
# 0         1001      Alabama       Autauga County     55036  26899   28137
# 1         1003      Alabama       Baldwin County    203360  99527  103833
# 2         1005      Alabama       Barbour County     26201  13976   12225
# 3         1007      Alabama          Bibb County     22580  12251   10329
# 4         1009      Alabama        Blount County     57667  28490   29177
# ...        ...          ...                  ...       ...    ...     ...
# 3215     72145  Puerto Rico  Vega Baja Municipio     54754  26269   28485
# 3216     72147  Puerto Rico    Vieques Municipio      8931   4351    4580
# 3217     72149  Puerto Rico   Villalba Municipio     23659  11510   12149
# 3218     72151  Puerto Rico    Yabucoa Municipio     35025  16984   18041
# 3219     72153  Puerto Rico      Yauco Municipio     37585  18052   19533
#
#       Hispanic  White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  \
# 0          2.7   75.4   18.9     0.3  ...   0.6          1.3         2.5
# 1          4.4   83.1    9.5     0.8  ...   0.8          1.1         5.6
# 2          4.2   45.7   47.8     0.2  ...   2.2          1.7         1.3
# 3          2.4   74.6   22.0     0.4  ...   0.3          1.7         1.5
# 4          9.0   87.4    1.5     0.3  ...   0.4          0.4         2.1
# ...        ...    ...    ...     ...  ...   ...          ...         ...
# 3215      96.7    3.1    0.1     0.0  ...   1.4          0.6         0.9
# 3216      95.7    4.0    0.0     0.0  ...   5.0          0.0         1.7
# 3217      99.7    0.2    0.1     0.0  ...   2.1          0.0         2.8
# 3218      99.9    0.1    0.0     0.0  ...   1.4          1.8         0.1
# 3219      99.8    0.2    0.0     0.0  ...   1.7          0.1         5.0
#
#       MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 0            25.8     24112         74.1        20.2           5.6
# 1            27.0     89527         80.7        12.9           6.3
# 2            23.4      8878         74.1        19.1           6.5
# 3            30.0      8171         76.0        17.4           6.3
# 4            35.0     21380         83.9        11.9           4.0
# ...           ...       ...          ...         ...           ...
# 3215         31.6     14234         76.2        19.3           4.3
# 3216         14.9      2927         40.7        40.9          18.4
# 3217         28.4      6873         59.2        30.2          10.4
# 3218         30.5      7878         62.7        30.9           6.3
# 3219         24.4      8995         66.4        28.7           5.0
#
#       FamilyWork  Unemployment
# 0            0.1           5.2
# 1            0.1           5.5
# 2            0.3          12.4
# 3            0.3           8.2
# 4            0.1           4.9
# ...          ...           ...
# 3215         0.2          16.8
# 3216         0.0          12.8
# 3217         0.2          24.8
# 3218         0.0          25.4
# 3219         0.0          24.0
#
# [3220 rows x 37 columns]

# %%
dfEdu
# Out:
#       FIPS Code State            Area name  2003 Rural-urban Continuum Code  \
# 0             0    US        United States                              NaN
# 1          1000    AL              Alabama                              NaN
# 2          1001    AL       Autauga County                              2.0
# 3          1003    AL       Baldwin County                              4.0
# 4          1005    AL       Barbour County                              6.0
# ...         ...   ...                  ...                              ...
# 3278      72145    PR  Vega Baja Municipio                              1.0
# 3279      72147    PR    Vieques Municipio                              7.0
# 3280      72149    PR   Villalba Municipio                              2.0
# 3281      72151    PR    Yabucoa Municipio                              1.0
# 3282      72153    PR      Yauco Municipio                              3.0
#
#       2003 Urban Influence Code  2013 Rural-urban Continuum Code  \
# 0                           NaN                              NaN
# 1                           NaN                              NaN
# 2                           2.0                              2.0
# 3                           5.0                              3.0
# 4                           6.0                              6.0
# ...                         ...                              ...
# 3278                        1.0                              1.0
# 3279                       12.0                              7.0
# 3280                        2.0                              2.0
# 3281                        1.0                              1.0
# 3282                        2.0                              2.0
#
#       2013 Urban Influence Code Less than a high school diploma, 1970  \
# 0                           NaN                            52,373,312
# 1                           NaN                             1,062,306
# 2                           2.0                                 6,611
# 3                           2.0                                18,726
# 4                           6.0                                 8,120
# ...                         ...                                   ...
# 3278                        1.0                                   NaN
# 3279                       12.0                                   NaN
# 3280                        2.0                                   NaN
# 3281                        1.0                                   NaN
# 3282                        2.0                                   NaN
#
#      High school diploma only, 1970 Some college (1-3 years), 1970  ...  \
# 0                        34,158,051                     11,650,730  ...
# 1                           468,269                        136,287  ...
# 2                             3,757                            933  ...
# 3                             8,426                          2,334  ...
# 4                             2,242                            581  ...
# ...                             ...                            ...  ...
# 3278                            NaN                            NaN  ...
# 3279                            NaN                            NaN  ...
# 3280                            NaN                            NaN  ...
# 3281                            NaN                            NaN  ...
# 3282                            NaN                            NaN  ...
#
#      Percent of adults completing some college or associate's degree, 2000  \
# 0                                                  27.4
# 1                                                  25.9
# 2                                                  26.9
# 3                                                  29.3
# 4                                                  21.3
# ...                                                 ...
# 3278                                               21.4
# 3279                                               13.7
# 3280                                               18.0
# 3281                                               18.3
# 3282                                               17.8
#
#       Percent of adults with a bachelor's degree or higher, 2000  \
# 0                                                  24.4
# 1                                                  19.0
# 2                                                  18.0
# 3                                                  23.1
# 4                                                  10.9
# ...                                                 ...
# 3278                                               14.4
# 3279                                               10.1
# 3280                                               12.8
# 3281                                               12.1
# 3282                                               15.8
#
#       Less than a high school diploma, 2015-19  \
# 0                                   26,472,261
# 1                                      458,922
# 2                                        4,291
# 3                                       13,893
# 4                                        4,812
# ...                                        ...
# 3278                                    10,494
# 3279                                     1,792
# 3280                                     3,330
# 3281                                     6,927
# 3282                                     6,794
#
#       High school diploma only, 2015-19  \
# 0                            59,472,748
# 1                             1,022,839
# 2                                12,551
# 3                                41,797
# 4                                 6,396
# ...                                 ...
# 3278                              9,681
# 3279                              2,440
# 3280                              5,809
# 3281                              6,132
# 3282                              8,512
#
#       Some college or associate's degree, 2015-19  \
# 0                                      63,756,905
# 1                                         993,344
# 2                                          10,596
# 3                                          47,274
# 4                                           4,676
# ...                                           ...
# 3278                                        8,905
# 3279                                          875
# 3280                                        2,987
# 3281                                        6,494
# 3282                                        3,973
#
#      Bachelor's degree or higher, 2015-19  \
# 0                              70,920,162
# 1                                 845,772
# 2                                   9,929
# 3                                  48,148
# 4                                   2,080
# ...                                   ...
# 3278                                7,834
# 3279                                1,121
# 3280                                3,015
# 3281                                4,293
# 3282                                6,304
#
#      Percent of adults with less than a high school diploma, 2015-19  \
# 0                                                  12.0
# 1                                                  13.8
# 2                                                  11.5
# 3                                                   9.2
# 4                                                  26.8
# ...                                                 ...
# 3278                                               28.4
# 3279                                               28.8
# 3280                                               22.0
# 3281                                               29.0
# 3282                                               26.6
#
#      Percent of adults with a high school diploma only, 2015-19  \
# 0                                                  27.0
# 1                                                  30.8
# 2                                                  33.6
# 3                                                  27.7
# 4                                                  35.6
# ...                                                 ...
# 3278                                               26.2
# 3279                                               39.2
# 3280                                               38.4
# 3281                                               25.7
# 3282                                               33.3
#
#      Percent of adults completing some college or associate's degree, 2015-19  \
# 0                                                  28.9
# 1                                                  29.9
# 2                                                  28.4
# 3                                                  31.3
# 4                                                  26.0
# ...                                                 ...
# 3278                                               24.1
# 3279                                               14.0
# 3280                                               19.7
# 3281                                               27.2
# 3282                                               15.5
#
#       Percent of adults with a bachelor's degree or higher, 2015-19
# 0                                                  32.1
# 1                                                  25.5
# 2                                                  26.6
# 3                                                  31.9
# 4                                                  11.6
# ...                                                 ...
# 3278                                               21.2
# 3279                                               18.0
# 3280                                               19.9
# 3281                                               18.0
# 3282                                               24.6
#
# [3283 rows x 47 columns]

# %% [markdown]
# ## Data process

# %% [markdown]
# ### data cleaning

# %%
# univeristy name, county tolower
dfInfo['NAME'] = dfInfo['NAME'].str.lower()
dfRank['institution'] = dfRank['institution'].str.lower()
dfInfo['COUNTY'] = dfInfo['COUNTY'].str.lower()
dfDemo['County'] = dfDemo['County'].str.replace(' County', '')
dfDemo['County'] = dfDemo['County'].str.lower()


# only use latest rank
dfRank = dfRank[dfRank.year == 2015]

# only need us university data
dfRank = dfRank[dfRank.country == "USA"]

# state name to state abbreviation
dfDemo['State'] = dfDemo['State'].map(us_state_to_abbrev).fillna(dfDemo['State'])

# %%
dfRank.shape
# Out:
# (229, 14)

# %% [markdown]
# ### data integration

# %%
# join rank data with university info we need
dfRank2 = dfRank.merge(dfInfo, left_on='institution', right_on='NAME')
dfRank2.columns
# Out:
# Index(['world_rank', 'institution', 'country', 'national_rank',
#        'quality_of_education', 'alumni_employment', 'quality_of_faculty',
#        'publications', 'influence', 'citations', 'broad_impact', 'patents',
#        'score', 'year', 'X', 'Y', 'OBJECTID', 'IPEDSID', 'NAME', 'ADDRESS',
#        'CITY', 'STATE', 'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS',
#        'POPULATION', 'COUNTY', 'COUNTYFIPS', 'COUNTRY', 'LATITUDE',
#        'LONGITUDE', 'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCEDATE',
#        'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'STFIPS', 'COFIPS', 'SECTOR',
#        'LEVEL_', 'HI_OFFER', 'DEG_GRANT', 'LOCALE', 'CLOSE_DATE', 'MERGE_ID',
#        'ALIAS', 'SIZE_SET', 'INST_SIZE', 'PT_ENROLL', 'FT_ENROLL',
#        'TOT_ENROLL', 'HOUSING', 'DORM_CAP', 'TOT_EMP', 'SHELTER_ID'],
#       dtype='object')

# %%
# join demographic data with education data
dfDemo2 = dfDemo.merge(dfEdu, left_on='CountyId', right_on='FIPS Code')
dfDemo2.head()
# Out:
#    CountyId State_x   County  TotalPop    Men   Women  Hispanic  White  Black  \
# 0      1001      AL  autauga     55036  26899   28137       2.7   75.4   18.9
# 1      1003      AL  baldwin    203360  99527  103833       4.4   83.1    9.5
# 2      1005      AL  barbour     26201  13976   12225       4.2   45.7   47.8
# 3      1007      AL     bibb     22580  12251   10329       2.4   74.6   22.0
# 4      1009      AL   blount     57667  28490   29177       9.0   87.4    1.5
#
#    Native  ...  \
# 0     0.3  ...
# 1     0.8  ...
# 2     0.2  ...
# 3     0.4  ...
# 4     0.3  ...
#
#    Percent of adults completing some college or associate's degree, 2000  \
# 0                                               26.9
# 1                                               29.3
# 2                                               21.3
# 3                                               20.4
# 4                                               24.8
#
#    Percent of adults with a bachelor's degree or higher, 2000  \
# 0                                               18.0
# 1                                               23.1
# 2                                               10.9
# 3                                                7.1
# 4                                                9.6
#
#    Less than a high school diploma, 2015-19  \
# 0                                     4,291
# 1                                    13,893
# 2                                     4,812
# 3                                     3,386
# 4                                     7,763
#
#    High school diploma only, 2015-19  \
# 0                             12,551
# 1                             41,797
# 2                              6,396
# 3                              7,256
# 4                             13,299
#
#    Some college or associate's degree, 2015-19  \
# 0                                       10,596
# 1                                       47,274
# 2                                        4,676
# 3                                        3,848
# 4                                       13,519
#
#    Bachelor's degree or higher, 2015-19  \
# 0                                 9,929
# 1                                48,148
# 2                                 2,080
# 3                                 1,678
# 4                                 5,210
#
#    Percent of adults with less than a high school diploma, 2015-19  \
# 0                                               11.5
# 1                                                9.2
# 2                                               26.8
# 3                                               20.9
# 4                                               19.5
#
#    Percent of adults with a high school diploma only, 2015-19  \
# 0                                               33.6
# 1                                               27.7
# 2                                               35.6
# 3                                               44.9
# 4                                               33.4
#
#    Percent of adults completing some college or associate's degree, 2015-19  \
# 0                                               28.4
# 1                                               31.3
# 2                                               26.0
# 3                                               23.8
# 4                                               34.0
#
#    Percent of adults with a bachelor's degree or higher, 2015-19
# 0                                               26.6
# 1                                               31.9
# 2                                               11.6
# 3                                               10.4
# 4                                               13.1
#
# [5 rows x 84 columns]

# %%
dfDemo2.shape
# Out:
# (3220, 84)

# %%
dfDemo.shape
# Out:
# (3220, 37)

# %%
dfEdu.shape
# Out:
# (3283, 47)

# %%
dfRank.shape
# Out:
# (229, 14)

# %%
dfRank2.shape
# Out:
# (134, 59)

# %%
# merge university info with demographic info
dfFinal = dfRank2.merge(dfDemo2, left_on=['COUNTY','STATE'], right_on=['County', 'State_x'])

# %%
dfFinal.shape
# Out:
# (125, 143)

# %%
dfFinal= dfFinal.sort_values(by=['world_rank'])

# %%
dfFinal.to_csv('final.csv')

# %% [markdown]
# ## Machine Learning

# %% [markdown]
# ### Feature selection

# %%
print([x for x in dfFinal.columns])
# Out:
# ['world_rank', 'institution', 'country', 'national_rank', 'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'score', 'year', 'X', 'Y', 'OBJECTID', 'IPEDSID', 'NAME', 'ADDRESS', 'CITY', 'STATE', 'ZIP', 'ZIP4', 'TELEPHONE', 'TYPE', 'STATUS', 'POPULATION', 'COUNTY', 'COUNTYFIPS', 'COUNTRY', 'LATITUDE', 'LONGITUDE', 'NAICS_CODE', 'NAICS_DESC', 'SOURCE', 'SOURCEDATE', 'VAL_METHOD', 'VAL_DATE', 'WEBSITE', 'STFIPS', 'COFIPS', 'SECTOR', 'LEVEL_', 'HI_OFFER', 'DEG_GRANT', 'LOCALE', 'CLOSE_DATE', 'MERGE_ID', 'ALIAS', 'SIZE_SET', 'INST_SIZE', 'PT_ENROLL', 'FT_ENROLL', 'TOT_ENROLL', 'HOUSING', 'DORM_CAP', 'TOT_EMP', 'SHELTER_ID', 'CountyId', 'State_x', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific', 'VotingAgeCitizen', 'Income', 'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty', 'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment', 'FIPS Code', 'State_y', 'Area name', '2003 Rural-urban Continuum Code', '2003 Urban Influence Code', '2013 Rural-urban Continuum Code', '2013 Urban Influence Code', 'Less than a high school diploma, 1970', 'High school diploma only, 1970', 'Some college (1-3 years), 1970', 'Four years of college or higher, 1970', 'Percent of adults with less than a high school diploma, 1970', 'Percent of adults with a high school diploma only, 1970', 'Percent of adults completing some college (1-3 years), 1970', 'Percent of adults completing four years of college or higher, 1970', 'Less than a high school diploma, 1980', 'High school diploma only, 1980', 'Some college (1-3 years), 1980', 'Four years of college or higher, 1980', 'Percent of adults with less than a high school diploma, 1980', 'Percent of adults with a high school diploma only, 1980', 'Percent of adults completing some college (1-3 years), 1980', 'Percent of adults completing four years of college or higher, 1980', 'Less than a high school diploma, 1990', 'High school diploma only, 1990', "Some college or associate's degree, 1990", "Bachelor's degree or higher, 1990", 'Percent of adults with less than a high school diploma, 1990', 'Percent of adults with a high school diploma only, 1990', "Percent of adults completing some college or associate's degree, 1990", "Percent of adults with a bachelor's degree or higher, 1990", 'Less than a high school diploma, 2000', 'High school diploma only, 2000', "Some college or associate's degree, 2000", "Bachelor's degree or higher, 2000", 'Percent of adults with less than a high school diploma, 2000', 'Percent of adults with a high school diploma only, 2000', "Percent of adults completing some college or associate's degree, 2000", "Percent of adults with a bachelor's degree or higher, 2000", 'Less than a high school diploma, 2015-19', 'High school diploma only, 2015-19', "Some college or associate's degree, 2015-19", "Bachelor's degree or higher, 2015-19", 'Percent of adults with less than a high school diploma, 2015-19', 'Percent of adults with a high school diploma only, 2015-19', "Percent of adults completing some college or associate's degree, 2015-19", "Percent of adults with a bachelor's degree or higher, 2015-19"]

# %%
# All factors(demographic info)
dfML = dfFinal[['world_rank', 'institution', 'STATE', 'COUNTY',
               'national_rank', 'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'score',
               'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"]
              ]
dfML.shape
# Out:
# (125, 34)

# %%
dfML2 = dfML.copy()

# %%
# put world_rank in buckets
dfML2 = dfML.copy()
for x in dfML2.world_rank:
    if x <= 200:
        dfML2.loc[dfML2['world_rank'] == x, ['world_rank']] = "1"
    else: dfML2.loc[dfML2['world_rank'] == x, ['world_rank']] = "0"

# %%
dfML2
# Out:
#     world_rank                                 institution STATE       COUNTY  \
# 0            1                          harvard university    MA    middlesex
# 5            1                         stanford university    CA  santa clara
# 1            1       massachusetts institute of technology    MA    middlesex
# 6            1                       university of chicago    IL         cook
# 12           1                        princeton university    NJ       mercer
# ..         ...                                         ...   ...          ...
# 120          0                 florida atlantic university    FL   palm beach
# 121          0  university of north carolina at greensboro    NC     guilford
# 122          0          university of southern mississippi    MS      forrest
# 123          0                          oakland university    MI      oakland
# 124          0                  university of north dakota    ND  grand forks
#
#      national_rank  quality_of_education  alumni_employment  \
# 0                1                     1                  1
# 5                2                     9                  2
# 1                3                     3                 11
# 6                6                    11                 14
# 12               7                     4                 15
# ..             ...                   ...                ...
# 120            221                   367                567
# 121            224                   367                567
# 122            225                   367                567
# 123            226                   367                567
# 124            227                   367                567
#
#      quality_of_faculty  publications  influence  ...  OtherTransp  \
# 0                     1             1          1  ...          2.4
# 5                     4             5          3  ...          3.1
# 1                     2            15          2  ...          2.4
# 6                     8            17         16  ...          2.4
# 12                    3            72         25  ...          1.9
# ..                  ...           ...        ...  ...          ...
# 120                 218           855        741  ...          2.0
# 121                 218           899        825  ...          1.0
# 122                 218           913        853  ...          8.3
# 123                 218           888        810  ...          0.8
# 124                 218           917        731  ...          2.0
#
#      WorkAtHome  MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 0           5.6         30.3    862873         82.9        10.7           6.2
# 5           4.8         28.0    967294         84.7         9.3           5.9
# 1           5.6         30.3    862873         82.9        10.7           6.2
# 6           4.5         32.9   2521437         84.2        11.1           4.6
# 12          5.0         28.3    181602         80.0        16.0           3.9
# ..          ...          ...       ...          ...         ...           ...
# 120         6.4         25.3    655496         83.1        10.0           6.7
# 121         5.5         21.5    246145         82.3        12.2           5.4
# 122         1.2         21.6     32089         77.9        18.8           3.2
# 123         4.5         26.7    629551         86.8         8.2           4.8
# 124         3.5         14.2     38387         74.5        21.3           3.9
#
#      FamilyWork  Unemployment  \
# 0           0.1           4.8
# 5           0.1           5.7
# 1           0.1           4.8
# 6           0.1           8.7
# 12          0.1           7.5
# ..          ...           ...
# 120         0.1           7.4
# 121         0.1           6.6
# 122         0.0          11.9
# 123         0.2           5.3
# 124         0.2           3.8
#
#      Percent of adults with a bachelor's degree or higher, 2015-19
# 0                                                 56.3
# 5                                                 52.4
# 1                                                 56.3
# 6                                                 38.8
# 12                                                42.6
# ..                                                 ...
# 120                                               36.7
# 121                                               36.0
# 122                                               27.8
# 123                                               47.2
# 124                                               35.6
#
# [125 rows x 34 columns]

# %%
# internal features 8 features
dfInternal = dfML2[['world_rank',
               'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents'
               ]
              ]
dfInternal.shape
# Out:
# (125, 9)

# %%
# external features 20 features
dfExternal = dfML2[['world_rank',
                'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]
              ]
dfExternal.shape
# Out:
# (125, 21)

# %%
# mixed features 29 features
dfMixed = dfML2[['world_rank',
               'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 
               'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"]
              ]
dfMixed.shape
# Out:
# (125, 29)

# %%
#dfML_inverse = dfML.copy()
#dfML_inverse['world_rank'] = 1 / dfML_inverse['world_rank']

# %%
#Using Pearson Correlation for internal factors
plt.figure(figsize=(12,10))
cor = dfML.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# ### Internal factors

# %%
internal_train, internal_test = np.split(dfInternal.sample(frac=1, random_state=42), 
                       [int(.8*len(dfInternal))])

# %% [markdown]
# #### Cross-validation

# %%
all_models = {
    'DecisionTree': tree.DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'LogisticRegression': Pipeline([        
        ('scale', StandardScaler()),        
        ('model', LogisticRegression())
    ]),
    'KNearestNeighbors': KNeighborsClassifier()
}

all_params = {
    'RandomForest':{ 
            "n_estimators"         : [50, 100, 200],
            'min_impurity_decrease': [0, 0.01, 0.02, 0.05, 0.1]
            },
    'DecisionTree': {
        'min_impurity_decrease'    : [0, 0.01, 0.02, 0.05, 0.1]
        },
    'LogisticRegression' : {
        'model__C'                 : 10**np.linspace(-7, 5, 100)
        },
    'KNearestNeighbors' : {
        'n_neighbors'              : [2,3,4]
    }
}

# %%
for name in all_models.keys():
    model = all_models[name]
    params = all_params[name]
    gscv = GridSearchCV(estimator = model, param_grid = params, cv = 10)
    gscv.fit(internal_train[['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents']], 
             internal_train["world_rank"])
    print(f"best parameters are: {gscv.best_estimator_}")
    print(f"accuracy is: {gscv.best_score_}")
# Out:
# best parameters are: DecisionTreeClassifier(min_impurity_decrease=0)
# accuracy is: 0.93
# best parameters are: RandomForestClassifier(min_impurity_decrease=0, n_estimators=50)
# accuracy is: 0.95
# best parameters are: Pipeline(steps=[('scale', StandardScaler()),
#                 ('model', LogisticRegression(C=0.012328467394420659))])
# accuracy is: 0.9400000000000001
# best parameters are: KNeighborsClassifier(n_neighbors=3)
# accuracy is: 0.93

# %% [markdown]
# #### Decision Tree

# %%
DT_model_internal = tree.DecisionTreeClassifier(min_impurity_decrease=0.02)
DT_model_internal = DT_model_internal.fit(internal_train[['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents']], 
                                            internal_train["world_rank"])

# %%
dot_data = tree.export_graphviz(DT_model_internal, out_file=None, 
                      feature_names=['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents'],  
                      class_names=["1", "0"],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)
#graph.render(format="png", filename="iris_tree")
graph

# %% [markdown]
# #### Logistic regression

# %%
LG_model_internal = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', LogisticRegression(C=0.012328467394420659))
])   
LG_model_internal.fit(internal_train[['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents']]
                      , internal_train["world_rank"]);

# %%
LG_model_internal.named_steps['model'].coef_
# Out:
# array([[-0.14636411, -0.11763797, -0.16540234, -0.19000916, -0.18524678,
#         -0.18291614, -0.18479107, -0.18604377]])

# %% [markdown]
# #### Random forests

# %%
RF_model_internal = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', RandomForestClassifier(min_impurity_decrease=0))
])
RF_model_internal.fit(internal_train[['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents']]
                      , internal_train["world_rank"]);

# %% [markdown]
# #### Knn

# %%
KNN_model_internal = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', KNeighborsClassifier(n_neighbors=3))
])
KNN_model_internal.fit(internal_train[['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents']]
                      , internal_train["world_rank"]);

# %% [markdown]
# #### Accuracy

# %%
def compute_accuracy(model, data, group):
    if group == 'internal':
        y_hat_class = model.predict(data[['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents']])
    elif  group == 'external':
        y_hat_class = model.predict(data[['TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"]])
    elif group == 'mixed':
        y_hat_class = model.predict(data[[
               'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 
               'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"]])
    
    y_obs = data["world_rank"]
    return sum(y_hat_class == y_obs) / len(y_hat_class)

# %%
def get_train_and_validation_accuracy(model, group):
    if group == 'internal':
        train_accuracy = compute_accuracy(model, internal_train, group)
        test_accuracy = compute_accuracy(model, internal_test, group)
    elif group == 'external':
        train_accuracy = compute_accuracy(model, external_train, group)
        test_accuracy = compute_accuracy(model, external_test, group)
    elif group == 'mixed':
        train_accuracy = compute_accuracy(model, mixed_train, group)
        test_accuracy = compute_accuracy(model, mixed_test, group)
        
    return train_accuracy, test_accuracy

# %%
# training accuracy of logistic regression
LG_model_internal_accuracy = get_train_and_validation_accuracy(LG_model_internal, 'internal')
LG_model_internal_accuracy
# Out:
# (0.95, 1.0)

# %%
# training accuracy of decision tree
DT_model_internal_accuracy = get_train_and_validation_accuracy(DT_model_internal, 'internal')
DT_model_internal_accuracy
# Out:
# (0.99, 0.96)

# %%
# training accuracy of Random forests
RF_model_internal_accuracy = get_train_and_validation_accuracy(RF_model_internal, 'internal')
RF_model_internal_accuracy
# Out:
# (1.0, 1.0)

# %%
# training accuracy of KNN
KNN_model_internal_accuracy = get_train_and_validation_accuracy(KNN_model_internal, 'internal')
KNN_model_internal_accuracy
# Out:
# (0.93, 0.92)

# %% [markdown]
# ### External factors

# %%
external_train, external_test = np.split(dfExternal.sample(frac=1, random_state=42), 
                       [int(.8*len(dfExternal))])

# %% [markdown]
# #### Uses cv to evaluate and find best

# %%
all_models2 = {
    'DecisionTree': tree.DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'LogisticRegression': Pipeline([        
        ('scale', StandardScaler()),        
        ('model', LogisticRegression())
    ]),
    'KNearestNeighbors': KNeighborsClassifier()
}

all_params2 = {
    'RandomForest':{ 
            "n_estimators"         : [50, 100, 200],
            'min_impurity_decrease': [0, 0.01, 0.02, 0.05, 0.1]
            },
    'DecisionTree': {
        'min_impurity_decrease'    : [0, 0.01, 0.02, 0.05, 0.1]
        },
    'LogisticRegression' : {
        'model__C'                 : 10**np.linspace(-10, 1, 100)
        },
    'KNearestNeighbors' : {
        'n_neighbors'              : [2,3,4]
    }
}

# %%
for name in all_models2.keys():
    model = all_models2[name]
    params = all_params2[name]
    gscv = GridSearchCV(estimator = model, param_grid = params, cv = 10)
    gscv.fit(external_train[['TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"]], 
             external_train["world_rank"])
    print(f"best parameters are: {gscv.best_estimator_}")
    print(f"accuracy is: {gscv.best_score_}")
# Out:
# best parameters are: DecisionTreeClassifier(min_impurity_decrease=0)
# accuracy is: 0.6199999999999999
# best parameters are: RandomForestClassifier(min_impurity_decrease=0.02)
# accuracy is: 0.63
# best parameters are: Pipeline(steps=[('scale', StandardScaler()),
#                 ('model', LogisticRegression(C=0.059948425031893966))])
# accuracy is: 0.65
# best parameters are: KNeighborsClassifier(n_neighbors=2)
# accuracy is: 0.6900000000000001

# %% [markdown]
# #### Decision Tree

# %%
DT_model_external = tree.DecisionTreeClassifier(min_impurity_decrease=0)
DT_model_external = DT_model_external.fit(external_train[[
                'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]],
                external_train["world_rank"])
dot_data = tree.export_graphviz(DT_model_external, out_file=None, 
                      feature_names=[
                'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"],  
                      class_names=["1", "0"],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)
#graph.render(format="png", filename="iris_tree")
graph

# %% [markdown]
# #### logistic regression

# %%
LG_model_external = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', LogisticRegression(C=0.059948425031893966))
])   
LG_model_external.fit(external_train[[
                'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]], external_train["world_rank"]);

# %%
LG_model_external.named_steps['model'].coef_
# Out:
# array([[ 0.12574296, -0.00580162,  0.07266982,  0.18125144, -0.11232178,
#          0.04860977, -0.02285827,  0.08034335, -0.01158686,  0.08482006,
#          0.04367688, -0.03186438,  0.04907153,  0.13050541,  0.10958345,
#         -0.1385242 ,  0.14033793,  0.17049572, -0.05568767,  0.17026546]])

# %% [markdown]
# #### random forest

# %%
RF_model_external = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', RandomForestClassifier(min_impurity_decrease=0.05, n_estimators=200))
])
RF_model_external.fit(external_train[[
                'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]], external_train["world_rank"]);

# %% [markdown]
# #### knn

# %%
KNN_model_external = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', KNeighborsClassifier(n_neighbors=2))
])
KNN_model_external.fit(external_train[[
                'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]],external_train["world_rank"]);

# %%
# training accuracy of logistic regression
LG_model_external_accuracy = get_train_and_validation_accuracy(LG_model_external, 'external')
LG_model_internal_accuracy
# Out:
# (0.95, 1.0)

# %%
# training accuracy of decision tree
DT_model_external_accuracy = get_train_and_validation_accuracy(DT_model_external, 'external')
DT_model_external_accuracy
# Out:
# (0.93, 0.6)

# %%
# training accuracy of Random forests
RF_model_external_accuracy = get_train_and_validation_accuracy(RF_model_external, 'external')
RF_model_external_accuracy
# Out:
# (0.72, 0.68)

# %%
# training accuracy of KNN
KNN_model_external_accuracy = get_train_and_validation_accuracy(KNN_model_external, 'external')
KNN_model_external_accuracy
# Out:
# (0.76, 0.64)

# %% [markdown]
# ### Mixed factors

# %%
mixed_train, mixed_test = np.split(dfMixed.sample(frac=1, random_state=42), 
                       [int(.8*len(dfMixed))])

# %%
all_models3 = {
    'DecisionTree': tree.DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'LogisticRegression': Pipeline([        
        ('scale', StandardScaler()),        
        ('model', LogisticRegression())
    ]),
    'KNearestNeighbors': KNeighborsClassifier()
}

all_params3 = {
    'RandomForest':{ 
            "n_estimators"         : [50, 100, 200],
            'min_impurity_decrease': [0, 0.01, 0.02, 0.05, 0.1]
            },
    'DecisionTree': {
        'min_impurity_decrease'    : [0, 0.01, 0.02, 0.05, 0.1]
        },
    'LogisticRegression' : {
        'model__C'                 : 10**np.linspace(-10, 1, 100)
        },
    'KNearestNeighbors' : {
        'n_neighbors'              : [2,3,4]
    }
}

# %%
for name in all_models3.keys():
    model = all_models3[name]
    params = all_params3[name]
    gscv = GridSearchCV(estimator = model, param_grid = params, cv = 10)
    gscv.fit(mixed_train[['quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"]], 
             mixed_train["world_rank"])
    print(f"best parameters are: {gscv.best_estimator_}")
    print(f"accuracy is: {gscv.best_score_}")
# Out:
# best parameters are: DecisionTreeClassifier(min_impurity_decrease=0.02)
# accuracy is: 0.9400000000000001

# %% [markdown]
# #### Decision Tree

# %%
DT_model_mixed = tree.DecisionTreeClassifier(min_impurity_decrease=0.01)
DT_model_mixed = DT_model_mixed.fit(mixed_train[[
                'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]],
                mixed_train["world_rank"])
dot_data = tree.export_graphviz(decision_tree_mixed, out_file=None, 
                      feature_names=[
                 'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"],  
                      class_names=["1", "0"],  
                      filled=True, rounded=True,  
                      special_characters=True)  
graph = graphviz.Source(dot_data)
#graph.render(format="png", filename="iris_tree")
graph

# %% [markdown]
# #### logistic regression

# %%
LG_model_mixed = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', LogisticRegression(C=0.059948425031893966))
])   
LG_model_mixed.fit(mixed_train[[
                'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]],
                mixed_train["world_rank"]);

# %%
LG_model_mixed.named_steps['model'].coef_

# %% [markdown]
# #### random forest

# %%
RF_model_mixed = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', RandomForestClassifier(min_impurity_decrease=0.02))
])
RF_model_mixed.fit(mixed_train[[
                'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]],
                mixed_train["world_rank"]);

# %% [markdown]
# #### knn

# %%
KNN_model_mixed = Pipeline([        
    ('scale', StandardScaler()),        
    ('model', KNeighborsClassifier(n_neighbors=2))
])
KNN_model_mixed.fit(mixed_train[[
                'quality_of_education', 'alumni_employment', 'quality_of_faculty', 'publications', 'influence', 'citations', 'broad_impact', 'patents', 'TotalPop', 'Income', 'IncomePerCap', 'Poverty', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork', 'Unemployment',
               "Percent of adults with a bachelor's degree or higher, 2015-19"
               ]],
                mixed_train["world_rank"]);

# %%
# training accuracy of logistic regression
LG_model_mixed_accuracy = get_train_and_validation_accuracy(LG_model_mixed, 'mixed')
LG_model_mixed_accuracy

# %%
# training accuracy of decision tree
DT_model_mixed_accuracy = get_train_and_validation_accuracy(DT_model_mixed, 'mixed')
DT_model_mixed_accuracy

# %%
# training accuracy of Random forests
RF_model_mixed_accuracy = get_train_and_validation_accuracy(RF_model_mixed, 'mixed')
RF_model_mixed_accuracy

# %%
# training accuracy of KNN
KNN_model_mixed_accuracy = get_train_and_validation_accuracy(KNN_model_mixed, 'mixed')
KNN_model_mixed_accuracy
